# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from datetime import datetime
import pandas as pd
import time
import matplotlib.pyplot as plt

# Initialize the service (make sure you're logged in)
your_api_key = "V_5F6RZPUb9GB37hSH3CQrQpdFX7WpfP2kek91zjo0Ml"
your_crn = "crn:v1:bluemix:public:quantum-computing:us-east:a/5e194ca79679454da57a2ad2d3e49a9d:749f65fa-d77a-44f6-913a-5a77858ae7aa::"


QiskitRuntimeService.save_account(
    channel="ibm_cloud",
    token=your_api_key,
    instance="crn:v1:bluemix:public:quantum-computing:us-east:a/5e194ca79679454da57a2ad2d3e49a9d:749f65fa-d77a-44f6-913a-5a77858ae7aa::",
    overwrite=True
)
service = QiskitRuntimeService()

# Choose a real backend (replace with your desired backend)
backend_name = "ibm_brisbane"
backend = service.backend(backend_name)

# Sampling parameters
interval_minutes = 10
duration_minutes = 1440 
num_samples = duration_minutes /interval_minutes

# Store data
timestamps = []
queue_depths = []

print(f"Collecting queue depth data for {backend_name}...")

for i in range(int(num_samples)):  # <-- cast here to be safe
    success = False
    attempts = 0
    max_attempts = 3

    # --- Retry logic for network hiccups ---
    while not success and attempts < max_attempts:
        try:
            status = backend.status()
            queue_depth = status.pending_jobs
            timestamps.append(datetime.now())
            queue_depths.append(queue_depth)

            print(f"[{timestamps[-1].strftime('%H:%M:%S')}] Queue depth: {queue_depth}")
            success = True
        except Exception as e:
            attempts += 1
            print(f"⚠️ Attempt {attempts} failed due to: {e}")
            print("Retrying in 30 seconds...")
            time.sleep(30)

    if not success:
        print("❌ Failed after 3 attempts. Logging as NaN.")
        timestamps.append(datetime.now())
        queue_depths.append(float('nan'))

    # Wait for next interval (unless last iteration)
    if i < num_samples - 1:
        print(f"Sleeping for {interval_minutes} minutes... ({i+1}/{num_samples})")
        time.sleep(interval_minutes * 60)


# Plot
plt.figure(figsize=(10,5))
plt.plot(df["timestamp"], df["queue_depth"], marker="o", linestyle="-")
plt.title(f"Queue Depth Over Time for {backend_name}")
plt.xlabel("Time")
plt.ylabel("Queue Depth")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Collecting queue depth data for ibm_brisbane...
# [16:30:41] Queue depth: 3660
# Sleeping for 10 minutes... (1/144.0)
# [16:40:42] Queue depth: 3660
# Sleeping for 10 minutes... (2/144.0)
# [16:50:43] Queue depth: 3657
# Sleeping for 10 minutes... (3/144.0)
# [17:00:44] Queue depth: 3657
# Sleeping for 10 minutes... (4/144.0)
# [17:10:44] Queue depth: 3657
# Sleeping for 10 minutes... (5/144.0)
# [17:20:46] Queue depth: 3657
# Sleeping for 10 minutes... (6/144.0)
# [17:30:47] Queue depth: 3657
# Sleeping for 10 minutes... (7/144.0)
# [17:40:47] Queue depth: 3657
# Sleeping for 10 minutes... (8/144.0)
# [17:50:47] Queue depth: 3657
# Sleeping for 10 minutes... (9/144.0)
# [18:00:48] Queue depth: 3657
# Sleeping for 10 minutes... (10/144.0)
# [18:10:50] Queue depth: 3657
# Sleeping for 10 minutes... (11/144.0)
# [18:20:52] Queue depth: 3657
# Sleeping for 10 minutes... (12/144.0)
# [18:30:53] Queue depth: 3657
# Sleeping for 10 minutes... (13/144.0)
# [18:40:54] Queue depth: 3658
# Sleeping for 10 minutes... (14/144.0)
# [18:50:55] Queue depth: 3657
# Sleeping for 10 minutes... (15/144.0)
# ⚠️ Attempt 1 failed due to: 'HTTPSConnectionPool(host=\'us-east.quantum-computing.cloud.ibm.com\', port=443): Max retries exceeded with url: /backends/ibm_brisbane/status (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD1B241240>: Failed to resolve \'us-east.quantum-computing.cloud.ibm.com\' ([Errno 11001] getaddrinfo failed)"))'
# Retrying in 30 seconds...
# ⚠️ Attempt 2 failed due to: 'HTTPSConnectionPool(host=\'us-east.quantum-computing.cloud.ibm.com\', port=443): Max retries exceeded with url: /backends/ibm_brisbane/status (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD1B243BB0>: Failed to resolve \'us-east.quantum-computing.cloud.ibm.com\' ([Errno 11001] getaddrinfo failed)"))'
# Retrying in 30 seconds...
# ⚠️ Attempt 3 failed due to: 'HTTPSConnectionPool(host=\'us-east.quantum-computing.cloud.ibm.com\', port=443): Max retries exceeded with url: /backends/ibm_brisbane/status (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD1B2411B0>: Failed to resolve \'us-east.quantum-computing.cloud.ibm.com\' ([Errno 11001] getaddrinfo failed)"))'
# Retrying in 30 seconds...
# ❌ Failed after 3 attempts. Logging as NaN.
# Sleeping for 10 minutes... (16/144.0)
# [20:24:04] Queue depth: 3656
# Sleeping for 10 minutes... (17/144.0)
# [20:34:58] Queue depth: 3656
# Sleeping for 10 minutes... (18/144.0)
# ⚠️ Attempt 1 failed due to: 'HTTPSConnectionPool(host=\'us-east.quantum-computing.cloud.ibm.com\', port=443): Max retries exceeded with url: /backends/ibm_brisbane/status (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD1B66C6D0>: Failed to resolve \'us-east.quantum-computing.cloud.ibm.com\' ([Errno 11001] getaddrinfo failed)"))'
# Retrying in 30 seconds...
# ⚠️ Attempt 2 failed due to: 'HTTPSConnectionPool(host=\'us-east.quantum-computing.cloud.ibm.com\', port=443): Max retries exceeded with url: /backends/ibm_brisbane/status (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD1B241D80>: Failed to resolve \'us-east.quantum-computing.cloud.ibm.com\' ([Errno 11001] getaddrinfo failed)"))'
# Retrying in 30 seconds...
# ⚠️ Attempt 3 failed due to: 'HTTPSConnectionPool(host=\'us-east.quantum-computing.cloud.ibm.com\', port=443): Max retries exceeded with url: /backends/ibm_brisbane/status (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD1B2405E0>: Failed to resolve \'us-east.quantum-computing.cloud.ibm.com\' ([Errno 11001] getaddrinfo failed)"))'
# Retrying in 30 seconds...
# ❌ Failed after 3 attempts. Logging as NaN.
# Sleeping for 10 minutes... (19/144.0)
# ⚠️ Attempt 1 failed due to: 'HTTPSConnectionPool(host=\'us-east.quantum-computing.cloud.ibm.com\', port=443): Max retries exceeded with url: /backends/ibm_brisbane/status (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001CD1B7F42E0>: Failed to resolve \'us-east.quantum-computing.cloud.ibm.com\' ([Errno 11001] getaddrinfo failed)"))'
# Retrying in 30 seconds...
# [22:12:33] Queue depth: 3668
# Sleeping for 10 minutes... (20/144.0)
# [22:22:34] Queue depth: 3687
# Sleeping for 10 minutes... (21/144.0)
# [22:32:36] Queue depth: 3687
# Sleeping for 10 minutes... (22/144.0)
# [22:42:37] Queue depth: 3687
# Sleeping for 10 minutes... (23/144.0)
# [22:52:38] Queue depth: 3687
# Sleeping for 10 minutes... (24/144.0)
# [23:02:39] Queue depth: 3687
# Sleeping for 10 minutes... (25/144.0)
